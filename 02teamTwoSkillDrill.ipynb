# %%
# Import Dependencies
import pandas as pd
import os

# %%
# Get the file path for running team one
team_two_file_path = os.path.join('../','Resources', 'team-2.csv')

# %%
# Read the CSV file into a DataFrame
team_two_df = pd.read_csv(team_two_file_path)
team_two_df
# Out:
#   runner_name coach_name  run_1  run_2  run_3  run_4
# 0        Ryan    Charles    2.0    2.0    2.0    2.1
# 1       Sarah    Charles    1.3    1.2    1.6    1.9
# 2        Brad    Charles    1.0    1.0    1.0    1.5

# %%
# Melt the DataFrame
team_two_df.melt()
# Out:
#        variable  value
# 0   runner_name   Ryan
# 1   runner_name  Sarah
# 2   runner_name   Brad
# 3         run_1    2.0
# 4         run_1    1.3
# 5         run_1    1.0
# 6         run_2    2.0
# 7         run_2    1.2
# 8         run_2    1.0
# 9         run_3    2.0
# 10        run_3    1.6
# 11        run_3    1.0
# 12        run_4    2.1
# 13        run_4    1.9
# 14        run_4    1.5

# %%
# Melt the DataFrame using the variable we'd like to keep in the long DF
team_two_df.melt(id_vars= 'runner_name')
# Out:
#    runner_name variable  value
# 0         Ryan    run_1    2.0
# 1        Sarah    run_1    1.3
# 2         Brad    run_1    1.0
# 3         Ryan    run_2    2.0
# 4        Sarah    run_2    1.2
# 5         Brad    run_2    1.0
# 6         Ryan    run_3    2.0
# 7        Sarah    run_3    1.6
# 8         Brad    run_3    1.0
# 9         Ryan    run_4    2.1
# 10       Sarah    run_4    1.9
# 11        Brad    run_4    1.5

# %%
# Melt the DataFrame using the variable we'd like to keep in the long DF
team_two_df.melt(id_vars= 'runner_name')
# Out:
#    runner_name variable  value
# 0         Ryan    run_1    2.0
# 1        Sarah    run_1    1.3
# 2         Brad    run_1    1.0
# 3         Ryan    run_2    2.0
# 4        Sarah    run_2    1.2
# 5         Brad    run_2    1.0
# 6         Ryan    run_3    2.0
# 7        Sarah    run_3    1.6
# 8         Brad    run_3    1.0
# 9         Ryan    run_4    2.1
# 10       Sarah    run_4    1.9
# 11        Brad    run_4    1.5

# %%
# Renaming the columns
team_two_df.melt(id_vars="runner_name", var_name="run", value_name="distance")
# Out:
#    runner_name    run  distance
# 0         Ryan  run_1       2.0
# 1        Sarah  run_1       1.3
# 2         Brad  run_1       1.0
# 3         Ryan  run_2       2.0
# 4        Sarah  run_2       1.2
# 5         Brad  run_2       1.0
# 6         Ryan  run_3       2.0
# 7        Sarah  run_3       1.6
# 8         Brad  run_3       1.0
# 9         Ryan  run_4       2.1
# 10       Sarah  run_4       1.9
# 11        Brad  run_4       1.5

# %%
# Remove coach name from DataFramea
del team_two_df['coach_name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\Netflix Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'coach_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-b611dbac6f47> in <module>
#       1 # Remove coach name from DataFramea
# ----> 2 del team_two_df['coach_name']
#
# ~\anaconda3\Netflix Anaconda\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    3964             # there was no match, this call should raise the appropriate
#    3965             # exception:
# -> 3966             loc = self.axes[-1].get_loc(key)
#    3967             self._mgr.idelete(loc)
#    3968
#
# ~\anaconda3\Netflix Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'coach_name'

# %%
# Show final result
final_df= team_two_df.melt(id_vars="runner_name", var_name="lap", value_name="distance")

# %%
# Save results to a file
final_df= team_two_df.to_csv("melted_running_df.csv", sep=',')
